# %% [markdown]
# # Energy Consumption Prediction for Smart Homes
# Goal: Build a regression model to predict energy consumption of home appliances based on temperature, humidity, and other environmental factors. Helps in designing energy-efficient smart home automation.

# %%
# Import necessary libraries
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn import tree 
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.feature_selection import f_regression
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from scipy.stats import randint
import joblib

# %% [markdown]
# # Data Preprocessing and EDA

# %%
df=pd.read_csv("energydata_complete.csv")
df
# Out:
#                    date  Appliances  lights         T1       RH_1         T2  \
# 0      11-01-2016 17:00          60      30  19.890000  47.596667  19.200000
# 1      11-01-2016 17:10          60      30  19.890000  46.693333  19.200000
# 2      11-01-2016 17:20          50      30  19.890000  46.300000  19.200000
# 3      11-01-2016 17:30          50      40  19.890000  46.066667  19.200000
# 4      11-01-2016 17:40          60      40  19.890000  46.333333  19.200000
# ...                 ...         ...     ...        ...        ...        ...
# 19730  27-05-2016 17:20         100       0  25.566667  46.560000  25.890000
# 19731  27-05-2016 17:30          90       0  25.500000  46.500000  25.754000
# 19732  27-05-2016 17:40         270      10  25.500000  46.596667  25.628571
# 19733  27-05-2016 17:50         420      10  25.500000  46.990000  25.414000
# 19734  27-05-2016 18:00         430      10  25.500000  46.600000  25.264286
#
#             RH_2         T3       RH_3         T4  ...         T9     RH_9  \
# 0      44.790000  19.790000  44.730000  19.000000  ...  17.033333  45.5300
# 1      44.722500  19.790000  44.790000  19.000000  ...  17.066667  45.5600
# 2      44.626667  19.790000  44.933333  18.926667  ...  17.000000  45.5000
# 3      44.590000  19.790000  45.000000  18.890000  ...  17.000000  45.4000
# 4      44.530000  19.790000  45.000000  18.890000  ...  17.000000  45.4000
# ...          ...        ...        ...        ...  ...        ...      ...
# 19730  42.025714  27.200000  41.163333  24.700000  ...  23.200000  46.7900
# 19731  42.080000  27.133333  41.223333  24.700000  ...  23.200000  46.7900
# 19732  42.768571  27.050000  41.690000  24.700000  ...  23.200000  46.7900
# 19733  43.036000  26.890000  41.290000  24.700000  ...  23.200000  46.8175
# 19734  42.971429  26.823333  41.156667  24.700000  ...  23.200000  46.8450
#
#        T_out  Press_mm_hg     RH_out  Windspeed  Visibility  Tdewpoint  \
# 0       6.60        733.5  92.000000   7.000000   63.000000        5.3
# 1       6.48        733.6  92.000000   6.666667   59.166667        5.2
# 2       6.37        733.7  92.000000   6.333333   55.333333        5.1
# 3       6.25        733.8  92.000000   6.000000   51.500000        5.0
# 4       6.13        733.9  92.000000   5.666667   47.666667        4.9
# ...      ...          ...        ...        ...         ...        ...
# 19730  22.70        755.2  55.666667   3.333333   23.666667       13.3
# 19731  22.60        755.2  56.000000   3.500000   24.500000       13.3
# 19732  22.50        755.2  56.333333   3.666667   25.333333       13.3
# 19733  22.30        755.2  56.666667   3.833333   26.166667       13.2
# 19734  22.20        755.2  57.000000   4.000000   27.000000       13.2
#
#              rv1        rv2
# 0      13.275433  13.275433
# 1      18.606195  18.606195
# 2      28.642668  28.642668
# 3      45.410390  45.410390
# 4      10.084097  10.084097
# ...          ...        ...
# 19730  43.096812  43.096812
# 19731  49.282940  49.282940
# 19732  29.199117  29.199117
# 19733   6.322784   6.322784
# 19734  34.118851  34.118851
#
# [19735 rows x 29 columns]

# %%
print("The shape of the dataset:",df.shape)
# Out:
# The shape of the dataset: (19735, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
#  18  RH_8         19735 non-null  float64
#  19  T9           19735 non-null  float64
#  20  RH_9         19735 non-null  float64
#  21  T_out        19735 non-null  float64
#  22  Press_mm_hg  19735 non-null  float64
#  23  RH_out       19735 non-null  float64
#  24  Windspeed    19735 non-null  float64
#  25  Visibility   19735 non-null  float64
#  26  Tdewpoint    19735 non-null  float64
#  27  rv1          19735 non-null  float64
#  28  rv2          19735 non-null  float64
# dtypes: float64(26), int64(2), object(1)
# memory usage: 4.4+ MB

# %%
print("The columns in the dataset:",df.columns)
# Out:
# The columns in the dataset: Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
missing_values = df.isnull().sum()
print("Missing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
duplicates = df.isnull().sum()
print("Duplicates in the dataset:")
print(duplicates)
# Out:
# Duplicates in the dataset:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
# This lineplot visualizes energy consumption (Appliances) across the dataset's timeline
plt.figure(figsize=(12, 5))
sns.lineplot(x=df.index, y=df["Appliances"])
plt.title("Appliance Energy Consumption Over Time")
plt.xlabel("Time (Index)")
plt.ylabel("Energy Consumption")
plt.show()

# %% [markdown]
# The energy consumption of appliances shows high variability over time with frequent spikes, indicating irregular usage patterns, while a consistent baseline suggests continuous or periodic usage of some appliances. There may also be cyclical trends influencing the fluctuations, which could be analyzed further.

# %%
# Drop unnecessary column
df.drop(columns=['date'], inplace=True)

# %%
# This scatter plot visualizes how outside temperature (T_out) affects energy consumption (Appliances).
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df["T_out"], y=df["Appliances"], alpha=0.5)
plt.title("Outside Temperature vs. Appliance Energy Consumption")
plt.xlabel("Outside Temperature (°C)")
plt.ylabel("Appliance Energy Usage")
plt.show()

# %% [markdown]
# The scatter plot shows that appliance energy usage is widely spread across different outside temperatures, with no strong correlation, though higher consumption is observed at various temperature ranges, possibly due to heating or cooling needs.

# %%
# This histogram with a KDE (Kernel Density Estimate) curve shows how the energy consumption (Appliances) is distributed across the dataset.
plt.figure(figsize=(8, 4))
sns.histplot(df['Appliances'], kde=True, color='skyblue')
plt.title('Distribution of Appliances Energy Use')
plt.xlabel('Appliances')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# The energy consumption of appliances is highly right-skewed, with most values concentrated under 200W and a few high-usage outliers above 1000W. This suggests frequent low usage and occasional spikes, indicating the need for transformation or robust models.

# %%
# This plot shows the relationship between outside temperature (T_out) and appliance energy usage (Appliances). Each point represents a single observation.
plt.figure(figsize=(8, 4))
sns.scatterplot(x='T_out', y='Appliances', data=df, alpha=0.5, color='green')
plt.title('T_out vs Appliances')
plt.xlabel('Outside Temperature (T_out)')
plt.ylabel('Appliances Energy Use')
plt.show()

# %% [markdown]
# This scatter plot shows no strong correlation between outside temperature (T_out) and appliance energy use — appliance usage remains highly variable regardless of temperature.

# %%
# A line plot showing how visibility and appliance usage change over the data’s index (which typically represents time).
plt.figure(figsize=(10, 4))
sns.lineplot(data=df[['Visibility', 'Appliances']])
plt.title('Visibility and Appliances Over Time')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend(['Visibility', 'Appliances'])
plt.show()

# %% [markdown]
# This plot shows that appliance energy use fluctuates significantly over time, while visibility remains relatively stable and does not appear to strongly influence appliance usage.

# %%
# A matrix of scatter plots and histograms showing pairwise relationships between selected features and Appliances.
sampled_df = df[['Appliances', 'T1', 'RH_1', 'T_out', 'Windspeed']].sample(500)  # Sample to improve speed
sns.pairplot(sampled_df)
plt.suptitle('Pairplot of Selected Features', y=1.02)
plt.show()

# %%
# This scatter plot visualizes the relationship between wind speed and energy usage.
plt.figure(figsize=(8, 4))
sns.scatterplot(x='Windspeed', y='Appliances', data=df, alpha=0.6, color='purple')
plt.title('Windspeed vs Appliances')
plt.xlabel('Windspeed')
plt.ylabel('Appliances Energy Use')
plt.show()

# %% [markdown]
# There is no strong correlation between windspeed and appliance energy use, as the data points are widely scattered across all windspeed values.

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df["Windspeed"], bins=30, kde=True)
plt.title("Distribution of Wind Speed")
plt.xlabel("Wind Speed (m/s)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# The histogram shows that wind speed is mostly low, with higher frequencies in the range of 0 to 5 m/s, and gradually decreases as wind speed increases.

# %%
df.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# std        4.069813      2.006111      3.254576      2.042884      4.341321
# min       20.463333     17.200000     28.766667     15.100000     27.660000
# 25%       37.900000     20.790000     36.900000     19.530000     35.530000
# 50%       40.500000     22.100000     38.530000     20.666667     38.400000
# 75%       43.260000     23.290000     41.760000     22.100000     42.156667
# max       56.026667     29.236000     50.163333     26.200000     51.090000
#
#        ...            T9          RH_9         T_out   Press_mm_hg  \
# count  ...  19735.000000  19735.000000  19735.000000  19735.000000
# mean   ...     19.485828     41.552401      7.412580    755.522602
# std    ...      2.014712      4.151497      5.318464      7.399441
# min    ...     14.890000     29.166667     -5.000000    729.300000
# 25%    ...     18.000000     38.500000      3.670000    750.933333
# 50%    ...     19.390000     40.900000      6.920000    756.100000
# 75%    ...     20.600000     44.338095     10.400000    760.933333
# max    ...     24.500000     53.326667     26.100000    772.300000
#
#              RH_out     Windspeed    Visibility     Tdewpoint           rv1  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      79.750418      4.039752     38.330834      3.760995     24.988033
# std       14.901088      2.451221     11.794719      4.195248     14.496634
# min       24.000000      0.000000      1.000000     -6.600000      0.005322
# 25%       70.333333      2.000000     29.000000      0.900000     12.497889
# 50%       83.666667      3.666667     40.000000      3.430000     24.897653
# 75%       91.666667      5.500000     40.000000      6.570000     37.583769
# max      100.000000     14.000000     66.000000     15.500000     49.996530
#
#                 rv2
# count  19735.000000
# mean      24.988033
# std       14.496634
# min        0.005322
# 25%       12.497889
# 50%       24.897653
# 75%       37.583769
# max       49.996530
#
# [8 rows x 28 columns]

# %%
print("Skewness values for each column:")
df.skew()
# Out:
# Skewness values for each column:
# Appliances     3.386367
# lights         2.195155
# T1             0.120917
# RH_1           0.465774
# T2             0.889658
# RH_2          -0.268247
# T3             0.450777
# RH_3           0.467589
# T4             0.170384
# RH_4           0.444614
# T5             0.558220
# RH_5           1.866820
# T6             0.597471
# RH_6          -0.241961
# T7             0.254722
# RH_7           0.242141
# T8            -0.256151
# RH_8           0.308036
# T9             0.382711
# RH_9           0.368937
# T_out          0.534302
# Press_mm_hg   -0.420442
# RH_out        -0.922997
# Windspeed      0.859982
# Visibility     0.441554
# Tdewpoint      0.239975
# rv1            0.004945
# rv2            0.004945
# dtype: float64

# %% [markdown]
# The ideal skewness value should be close to 0 for a normal distribution. However, in practical scenarios:
# * -0.5 to 0.5 → Fairly Symmetrical
# * -1 to -0.5 or 0.5 to 1 → Moderately Skewed
# * Less than -1 or Greater than 1 → Highly Skewed

# %% [markdown]
# Highly Skewed (Needs Transformation)
# * Appliances (3.386367) → Strongly right-skewed
# * lights (2.195155) → Highly right-skewed
# * RH_5 (1.866820) → Highly right-skewed
# * Windspeed (0.859982) → Moderately right-skewed
#
# Moderately Skewed (Mild Transformation May Help)
# * T2 (0.889658) → Right-skewed
# * T_out (0.534302) → Right-skewed
# * RH_9 (0.368937) → Slight right skew
# * T9 (0.382711) → Slight right skew
#
# Fairly Symmetrical (No Transformation Needed)
# * Tdewpoint (0.239975), RH_7 (0.242141), T7 (0.254722) → Close to normal distribution
#
# Moderately Left-Skewed
# * RH_out (-0.922997) → Moderately left-skewed
# * Press_mm_hg (-0.420442) → Slight left skew
# * T8 (-0.256151) → Slight left skew

# %%
# Plot the original distribution of Appliances
plt.figure(figsize=(10, 5))
sns.histplot(df["Appliances"], bins=50, kde=True, color='blue')
plt.title("Original Distribution of Appliances Energy Consumption")
plt.xlabel("Appliances Energy Consumption")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# The histogram shows that most appliances consume low energy, with frequency decreasing as energy consumption increases.

# %%
# Boxplot to view outliers
plt.figure(figsize=(12, 8))
sns.boxplot(df)
plt.xticks(rotation=90)
plt.title('Boxplot of  Features')
plt.show()

# %% [markdown]
# Columns That Should Be Transformed (Highly Skewed)
# 1. Right-Skewed
# * Appliances (3.386367)
# * lights (2.195155)
# * RH_5 (1.866820)
# * Windspeed (0.859982)
# * T2 (0.889658)
#
# 2. Left-Skewed
# * RH_out (-0.922997)

# %%
# Apply Log Transformation for columns - "Appliances", "lights", "RH_5", "Windspeed", "T2"
cols_to_log = ["Appliances", "lights", "RH_5", "Windspeed", "T2"]
df[cols_to_log] = np.log1p(df[cols_to_log])

# %%
# Apply IQR transformation method for column - "RH_out"
Q1 = df["RH_out"].quantile(0.25)
Q3 = df["RH_out"].quantile(0.75)
IQR = Q3 - Q1

# Define bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove outliers
df = df[(df["RH_out"] >= lower_bound) & (df["RH_out"] <= upper_bound)]

# %%
# Review skewness
df.skew()
# Out:
# Appliances     1.190418
# lights         1.392110
# T1             0.117512
# RH_1           0.528765
# T2             0.580099
# RH_2          -0.069142
# T3             0.467066
# RH_3           0.468824
# T4             0.185610
# RH_4           0.449892
# T5             0.571855
# RH_5           1.261486
# T6             0.555091
# RH_6          -0.253443
# T7             0.273993
# RH_7           0.234134
# T8            -0.242122
# RH_8           0.303955
# T9             0.401014
# RH_9           0.357046
# T_out          0.459814
# Press_mm_hg   -0.418716
# RH_out        -0.774234
# Windspeed     -0.035791
# Visibility     0.440530
# Tdewpoint      0.235035
# rv1            0.004173
# rv2            0.004173
# dtype: float64

# %%
# Handle skewness for the 2nd time

# %%
cols_to_log = ["Appliances", "lights"]
df[cols_to_log] = np.log1p(df[cols_to_log])

# %%
Q1 = df["RH_out"].quantile(0.25)
Q3 = df["RH_out"].quantile(0.75)
IQR = Q3 - Q1

# Define bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove outliers
df = df[(df["RH_out"] >= lower_bound) & (df["RH_out"] <= upper_bound)]

# %%
df.skew()
# Out:
# Appliances     0.805079
# lights         1.318499
# T1             0.120448
# RH_1           0.530693
# T2             0.580864
# RH_2          -0.042579
# T3             0.470631
# RH_3           0.466542
# T4             0.190053
# RH_4           0.447610
# T5             0.575930
# RH_5           1.269635
# T6             0.552760
# RH_6          -0.255813
# T7             0.277709
# RH_7           0.232455
# T8            -0.238394
# RH_8           0.301088
# T9             0.404629
# RH_9           0.353665
# T_out          0.455323
# Press_mm_hg   -0.417631
# RH_out        -0.753350
# Windspeed     -0.033386
# Visibility     0.440177
# Tdewpoint      0.233594
# rv1            0.004036
# rv2            0.004036
# dtype: float64

# %%
# Handle skewness for the 3rd time

# %%
cols_to_log = ["Appliances", "lights","RH_5"]
df[cols_to_log] = np.log1p(df[cols_to_log])

# %%
Q1 = df["RH_out"].quantile(0.25)
Q3 = df["RH_out"].quantile(0.75)
IQR = Q3 - Q1

# Define bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove outliers
df = df[(df["RH_out"] >= lower_bound) & (df["RH_out"] <= upper_bound)]

# %%
# Review skewness
df.skew()
# Out:
# Appliances     0.651369
# lights         1.301933
# T1             0.120448
# RH_1           0.530693
# T2             0.580864
# RH_2          -0.042579
# T3             0.470631
# RH_3           0.466542
# T4             0.190053
# RH_4           0.447610
# T5             0.575930
# RH_5           1.151602
# T6             0.552760
# RH_6          -0.255813
# T7             0.277709
# RH_7           0.232455
# T8            -0.238394
# RH_8           0.301088
# T9             0.404629
# RH_9           0.353665
# T_out          0.455323
# Press_mm_hg   -0.417631
# RH_out        -0.753350
# Windspeed     -0.033386
# Visibility     0.440177
# Tdewpoint      0.233594
# rv1            0.004036
# rv2            0.004036
# dtype: float64

# %% [markdown]
# Applying outlier removal multiple times (more than necessary) can lead to data inconsistencies and information loss. The dataset is now well-balanced with minimal skewness

# %%
df.shape
# Out:
# (19441, 28)

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(df)
plt.xticks(rotation=90)
plt.title('Boxplot of  Features')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df["Appliances"], bins=50, kde=True, color='blue')
plt.title("Original Distribution of Appliances Energy Consumption")
plt.xlabel("Appliances Energy Consumption")
plt.ylabel("Frequency")
plt.show()

# %%
# Correlation Matrix 
plt.figure(figsize=(20,8))
sns.heatmap(df.corr(), annot=True, cmap='viridis')
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.title('Correlation Matrix of  Features')
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
# Separate features and target variable
X = df.drop(columns=['Appliances'])
y = df['Appliances']

# %%
X,y
# Out:
# (         lights         T1       RH_1        T2       RH_2         T3  \
#  0      0.912001  19.890000  47.596667  3.005683  44.790000  19.790000
#  1      0.912001  19.890000  46.693333  3.005683  44.722500  19.790000
#  2      0.912001  19.890000  46.300000  3.005683  44.626667  19.790000
#  3      0.936268  19.890000  46.066667  3.005683  44.590000  19.790000
#  4      0.936268  19.890000  46.333333  3.005683  44.530000  19.790000
#  ...         ...        ...        ...       ...        ...        ...
#  19730  0.000000  25.566667  46.560000  3.291754  42.025714  27.200000
#  19731  0.000000  25.500000  46.500000  3.286684  42.080000  27.133333
#  19732  0.798928  25.500000  46.596667  3.281985  42.768571  27.050000
#  19733  0.798928  25.500000  46.990000  3.273894  43.036000  26.890000
#  19734  0.798928  25.500000  46.600000  3.268210  42.971429  26.823333
#
#              RH_3         T4       RH_4         T5  ...         T9     RH_9  \
#  0      44.730000  19.000000  45.566667  17.166667  ...  17.033333  45.5300
#  1      44.790000  19.000000  45.992500  17.166667  ...  17.066667  45.5600
#  2      44.933333  18.926667  45.890000  17.166667  ...  17.000000  45.5000
#  3      45.000000  18.890000  45.723333  17.166667  ...  17.000000  45.4000
#  4      45.000000  18.890000  45.530000  17.200000  ...  17.000000  45.4000
#  ...          ...        ...        ...        ...  ...        ...      ...
#  19730  41.163333  24.700000  45.590000  23.200000  ...  23.200000  46.7900
#  19731  41.223333  24.700000  45.590000  23.230000  ...  23.200000  46.7900
#  19732  41.690000  24.700000  45.730000  23.230000  ...  23.200000  46.7900
#  19733  41.290000  24.700000  45.790000  23.200000  ...  23.200000  46.8175
#  19734  41.156667  24.700000  45.963333  23.200000  ...  23.200000  46.8450
#
#         T_out  Press_mm_hg     RH_out  Windspeed  Visibility  Tdewpoint  \
#  0       6.60        733.5  92.000000   2.079442   63.000000        5.3
#  1       6.48        733.6  92.000000   2.036882   59.166667        5.2
#  2       6.37        733.7  92.000000   1.992430   55.333333        5.1
#  3       6.25        733.8  92.000000   1.945910   51.500000        5.0
#  4       6.13        733.9  92.000000   1.897120   47.666667        4.9
#  ...      ...          ...        ...        ...         ...        ...
#  19730  22.70        755.2  55.666667   1.466337   23.666667       13.3
#  19731  22.60        755.2  56.000000   1.504077   24.500000       13.3
#  19732  22.50        755.2  56.333333   1.540445   25.333333       13.3
#  19733  22.30        755.2  56.666667   1.575536   26.166667       13.2
#  19734  22.20        755.2  57.000000   1.609438   27.000000       13.2
#
#               rv1        rv2
#  0      13.275433  13.275433
#  1      18.606195  18.606195
#  2      28.642668  28.642668
#  3      45.410390  45.410390
#  4      10.084097  10.084097
#  ...          ...        ...
#  19730  43.096812  43.096812
#  19731  49.282940  49.282940
#  19732  29.199117  29.199117
#  19733   6.322784   6.322784
#  19734  34.118851  34.118851
#
#  [19441 rows x 27 columns],
#  0        0.967505
#  1        0.967505
#  2        0.953860
#  3        0.953860
#  4        0.967505
#             ...
#  19730    1.002638
#  19731    0.995738
#  19732    1.060353
#  19733    1.082477
#  19734    1.083604
#  Name: Appliances, Length: 19441, dtype: float64)

# %% [markdown]
# ANOVA F-test scores plot helps in selecting the most important features for the prediction model.

# %%
# Compute ANOVA F-scores
f_scores, _ = f_regression(X, y)
# Plot feature importance
plt.figure(figsize=(12, 5))
plt.bar(range(len(X.columns)), f_scores, tick_label=X.columns)
plt.xticks(rotation=90)
plt.xlabel("Features")
plt.ylabel("F-score")
plt.title("ANOVA F-test Scores for Feature Selection")
plt.show()

# %% [markdown]
# With the help of above bar graph, 6 features are removed, making k value 21

# %%
# Standardize numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Apply ANOVA F-test on X_scaled
select_k = SelectKBest(score_func=f_regression, k=21)  
X_selected = select_k.fit_transform(X_scaled, y)
# Get selected feature names and scores
selected_features = X.columns[select_k.get_support()]
selected_scores = select_k.scores_[select_k.get_support()]

# %%
selected_features
# Out:
# Index(['lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3', 'T4', 'T5', 'T6', 'RH_6',
#        'T7', 'RH_7', 'T8', 'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg',
#        'RH_out', 'Windspeed', 'Tdewpoint'],
#       dtype='object')

# %%
# Store results in a DataFrame
feature_importance = pd.DataFrame({'Feature': selected_features, 'Score': selected_scores})
feature_importance = feature_importance.sort_values(by='Score', ascending=False)
# Print the significant features
print("Top 21 Significant Features Affecting Energy consumption:")
print(feature_importance)
# Out:
# Top 21 Significant Features Affecting Energy consumption:
#         Feature        Score
# 0        lights  1602.021869
# 18       RH_out  1220.128577
# 3            T2  1219.154789
# 8            T6   931.363466
# 16        T_out   752.922446
# 9          RH_6   747.631527
# 5            T3   708.676255
# 1            T1   702.639784
# 12           T8   675.894884
# 13         RH_8   624.686289
# 6            T4   485.848796
# 7            T5   361.154899
# 10           T7   351.181637
# 15         RH_9   306.214943
# 14           T9   266.433290
# 19    Windspeed   216.088432
# 11         RH_7   193.402350
# 4          RH_2   173.606814
# 2          RH_1   152.646239
# 17  Press_mm_hg   146.874706
# 20    Tdewpoint    96.147645

# %% [markdown]
# # Model Training and Evaluation

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=42)

# %% [markdown]
# Implement the following five regression algorithms:
# 1) Linear Regression
# 2) Decision Tree Regressor
# 3) Random Forest Regressor
# 4) Gradient Boosting Regressor
# 5) Support Vector Regressor

# %%
# Define models
models = {
    "Linear Regression": LinearRegression(),
    "Decision Tree Regressor": DecisionTreeRegressor(random_state=42),
    "Random Forest Regressor": RandomForestRegressor(n_estimators=100, random_state=42),
    "Gradient Boosting Regressor": GradientBoostingRegressor(n_estimators=100, random_state=42),
    "Support Vector Regressor": SVR(kernel='linear')
}

# %%
# Evaluate models
results = []
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    r2 = r2_score(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    results.append({"Model": name, "R2 Score": r2, "MSE": mse, "MAE": mae})

# Convert results to DataFrame and sort by R2 Score
results_df = pd.DataFrame(results).sort_values(by="R2 Score", ascending=False)

# %%
# Print model performance
print("Model Performance Comparison:")
print(results_df)

# Identify the best performing model
best_model = results_df.iloc[0]
print("\nBest Performing Model:")
print(best_model)
# Out:
# Model Performance Comparison:
#                          Model  R2 Score       MSE       MAE
# 2      Random Forest Regressor  0.691910  0.000576  0.016238
# 1      Decision Tree Regressor  0.425360  0.001075  0.020678
# 3  Gradient Boosting Regressor  0.399331  0.001124  0.023909
# 0            Linear Regression  0.283814  0.001340  0.026332
# 4     Support Vector Regressor  0.158352  0.001575  0.031155
#
# Best Performing Model:
# Model       Random Forest Regressor
# R2 Score                    0.69191
# MSE                        0.000576
# MAE                        0.016238
# Name: 2, dtype: object

# %% [markdown]
# Based on the model performance comparison, the Random Forest Regressor is the best-performing model for predicting energy consumption in smart homes. It achieved:
# * Highest R² Score: 0.6919, indicating that it explains about 69.19% of the variance in the target variable.
# * Lowest Mean Squared Error (MSE): 0.000576, meaning it has the least prediction error compared to other models.
# * Lowest Mean Absolute Error (MAE): 0.016238, showing that its predictions are closer to actual values on average.
# Other models like Decision Tree, Gradient Boosting, Linear Regression, and Support Vector Regression performed worse, with significantly lower R² scores and higher errors.
# Thus, Random Forest Regressor is the most reliable model for this dataset and should be considered for deployment or further optimization.

# %%
# Train Decision Tree
dt_model = DecisionTreeRegressor(random_state=42)
dt_model.fit(X_train, y_train)

# Plot the Decision Tree
plt.figure(figsize=(20, 10))
tree.plot_tree(dt_model, filled=True, feature_names=df.drop(columns=['Appliances']).columns)
plt.title("Decision Tree Regressor")
plt.show()

# %% [markdown]
# # Hyper Parameter Tuning

# %%
models2 = {
    "Linear Regression": LinearRegression(),
    "Decision Tree Regressor": DecisionTreeRegressor(random_state=42),
    "Random Forest Regressor": RandomForestRegressor(n_estimators=100, random_state=42),
    "Gradient Boosting Regressor": GradientBoostingRegressor(n_estimators=100, random_state=42),
    "Support Vector Regressor": SVR(kernel='linear')
}

# %%
# Hyperparameter grids
param_grids = {
    "Linear Regression": {},  # No tunable hyperparameters for basic LinearRegression

    "Decision Tree Regressor": {
        "max_depth": [None, 5, 10, 20],
        "min_samples_split": [2, 5, 10]
    },

    "Random Forest Regressor": {
        "n_estimators": [50, 100],
        "max_depth": [None, 10, 20],
        "min_samples_split": [2, 5]
    },

    "Gradient Boosting Regressor": {
        "n_estimators": [100, 200],
        "learning_rate": [0.01, 0.1],
        "max_depth": [3, 5]
    },

    "Support Vector Regressor": {
        "C": [0.1, 1, 10],
        "epsilon": [0.1, 0.2, 0.5],
        "kernel": ['linear'] 
    }
}

# %%
# Train and Evaluate each model with GridSearchCV and print R² score
results = []
for name, model in models2.items():
    grid = GridSearchCV(model, param_grids[name], cv=3, scoring='r2', n_jobs=-1)
    grid.fit(X_train, y_train)
    y_pred = grid.best_estimator_.predict(X_test)
    results.append({"Model": name, "R2 Score": r2_score(y_test, y_pred)})

# Display results
results_df = pd.DataFrame(results).sort_values(by="R2 Score", ascending=False)
print(results_df)
# Out:
#                          Model  R2 Score
# 2      Random Forest Regressor  0.691910
# 3  Gradient Boosting Regressor  0.585534
# 1      Decision Tree Regressor  0.430071
# 0            Linear Regression  0.283814
# 4     Support Vector Regressor  0.158352

# %% [markdown]
# 1. Random Forest Regressor: R² score of 0.6919 – This model performs the best among the options, explaining approximately 69.19% of the variance in the data.
# 2. Gradient Boosting Regressor: R² score of 0.5855 – This model also performs quite well, explaining about 58.55% of the variance.
# 3. Decision Tree Regressor: R² score of 0.4301 – This model has a lower performance, explaining only 43.01% of the variance.
# 4. Linear Regression: R² score of 0.2838 – This model has the lowest performance, with only about 28.38% of the variance explained.
# 5. Support Vector Regressor: R² score of 0.1584 – This model is the least effective, explaining just 15.84% of the variance.

# %%
# Define distribution for RandomizedSearchCV
param_dist = {
    'n_estimators': randint(50, 200),
    'max_depth': randint(5, 30),
    'min_samples_split': randint(2, 15)
}
# Random Search
random_search = RandomizedSearchCV(RandomForestRegressor(), param_distributions=param_dist, n_iter=10, cv=5, random_state=42)
random_search.fit(X_train, y_train)
print("Best Params (Random Search):", random_search.best_params_)
# Out:
# Best Params (Random Search): {'max_depth': 26, 'min_samples_split': 6, 'n_estimators': 51}

# %%
# Use best params from Random Search
best_params = random_search.best_params_

# %%
# Build pipeline
pipeline = Pipeline(steps=[
    ('scaler', StandardScaler()),
    ('model', RandomForestRegressor(**best_params, random_state=42))
])

# Fit the pipeline
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model',
#                  RandomForestRegressor(max_depth=26, min_samples_split=6,
#                                        n_estimators=51, random_state=42))])

# %%
# Predicting using the pipeline
predictions = pipeline.predict(X_test)

# %%
# Save the model
joblib.dump(pipeline, 'best_EnergyConsumption_model.pkl')
# Out:
# ['best_EnergyConsumption_model.pkl']

# %% [markdown]
# # Unseen Data Check

# %%
unseen_df = pd.read_csv('synthetic_energydata_1500.csv')

# %%
missing_values = df.isnull().sum()
print("Missing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
duplicates = df.isnull().sum()
print("Duplicates in the dataset:")
print(duplicates)
# Out:
# Duplicates in the dataset:
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
# Features and target
X = unseen_df.drop(columns=['Appliances'])
y_true = unseen_df['Appliances']

# %%
# Predict directly using the pipeline
y_pred = pipeline.predict(X)
# Add predictions to DataFrame
unseen_df['predicted_energy'] = y_pred

# %%
#Unseen df with predictions
unseen_df
# Out:
#       lights         T1       RH_1         T2       RH_2     T3         T4  \
# 0          0  21.323333  37.730000  19.890000  38.566667  22.70  19.700000
# 1          0  21.790000  35.560000  20.434000  35.116000  21.20  21.100000
# 2          0  20.290000  35.700000  18.200000  37.590000  20.10  18.200000
# 3          0  22.390000  43.700000  22.000000  42.066667  22.70  21.290000
# 4          0  21.760000  40.900000  19.390000  43.090000  23.00  21.500000
# ...      ...        ...        ...        ...        ...    ...        ...
# 1495       0  19.260000  45.290000  18.500000  45.060000  19.70  18.200000
# 1496       0  25.100000  39.790000  28.000000  32.090000  26.10  25.100000
# 1497       0  22.166667  42.860000  21.323333  41.990000  22.39  19.600000
# 1498       0  24.890000  39.163333  22.225714  41.225714  24.89  25.100000
# 1499      10  19.600000  36.930000  17.323333  39.760000  19.79  22.133333
#
#              T5         T6       RH_6  ...       RH_8         T9       RH_9  \
# 0     19.200000  10.890000  28.633333  ...  43.645000  19.390000  41.266667
# 1     18.050000   1.200000  96.833333  ...  39.475000  18.500000  41.466667
# 2     18.500000  -2.090000  82.900000  ...  41.700000  17.890000  39.466667
# 3     19.700000  17.893333  20.223333  ...  47.000000  20.290000  44.290000
# 4     20.100000   9.500000  48.826667  ...  45.466667  20.356667  40.560000
# ...         ...        ...        ...  ...        ...        ...        ...
# 1495  17.200000   6.560000  85.426667  ...  46.515000  17.100000  46.645000
# 1496  23.100000  27.660000   1.000000  ...  39.897143  23.100000  42.163333
# 1497  19.688889   3.930000  92.656667  ...  45.645556  19.000000  44.000000
# 1498  23.890000   9.160000  24.796667  ...  41.700000  23.890000  45.400000
# 1499  17.390000   6.560000  37.766667  ...  38.626667  17.390000  36.326667
#
#       T_out  Press_mm_hg     RH_out  Windspeed  Tdewpoint  Appliances  \
# 0      6.65   758.650000  85.500000   1.000000      4.350         130
# 1      2.07   765.033333  64.333333   1.333333     -4.070          80
# 2     -1.07   754.900000  87.000000   3.666667     -2.930          30
# 3     17.30   749.500000  66.000000   2.000000     10.900         120
# 4      9.57   750.466667  77.666667   6.666667      5.830          60
# ...     ...          ...        ...        ...        ...         ...
# 1495   7.25   765.200000  70.500000   2.000000      2.150          40
# 1496  24.40   751.833333  42.666667   3.833333     10.900          50
# 1497   3.75   731.550000  95.500000   6.500000      3.050         200
# 1498   8.65   754.050000  82.833333   2.333333      5.830          70
# 1499   6.17   746.266667  63.833333   4.833333     -0.267          90
#
#       predicted_energy
# 0             1.031490
# 1             1.024332
# 2             1.022050
# 3             1.031490
# 4             1.031490
# ...                ...
# 1495          1.025198
# 1496          1.031490
# 1497          1.031490
# 1498          1.031490
# 1499          1.025318
#
# [1500 rows x 23 columns]

# %%
# Predicted values
y_pred = unseen_df['predicted_energy']

# Calculate metrics
mae = mean_absolute_error(y_true, y_pred)
mse = mean_squared_error(y_true, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_true, y_pred)

# Print results
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R-squared (R²):", r2)
# Out:
# Mean Absolute Error (MAE): 96.63258367604516
# Mean Squared Error (MSE): 19338.134906065072
# Root Mean Squared Error (RMSE): 139.06162269319697
# R-squared (R²): -0.9337765425827
